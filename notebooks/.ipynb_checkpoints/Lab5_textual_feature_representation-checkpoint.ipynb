# %% [markdown]
# # Lab 5 : Textual Feature Representation

# %% [markdown]
# ## 65070501050 | Wongsatorn Sungsilapawech

# %% [markdown]
# ## Preprocess

# %%
import pickle
import pandas as pd

# %%
data = pd.read_pickle('consumer_complaint_dataset.data', compression='gzip')

# %%
data.head()
# Out:
#                                                topic  \
# 0                                    Debt collection
# 1  Credit reporting, credit repair services, or o...
# 2                                    Debt collection
# 3  Credit reporting, credit repair services, or o...
# 4  Credit reporting, credit repair services, or o...
#
#                                                input
# 0  transworld systems inc. \nis trying to collect...
# 1  I would like to request the suppression of the...
# 2  Over the past 2 weeks, I have been receiving e...
# 3  I HAD FILED WITH CFPB ON XX/XX/XXXX19 TO HAVE ...
# 4  I have several accounts that the balance is in...

# %%
data = data[0:500]

# %%
data['input']
# Out:
# 0      transworld systems inc. \nis trying to collect...
# 1      I would like to request the suppression of the...
# 2      Over the past 2 weeks, I have been receiving e...
# 3      I HAD FILED WITH CFPB ON XX/XX/XXXX19 TO HAVE ...
# 4      I have several accounts that the balance is in...
#                              ...
# 495    On XX/XX/XXXX, out of desperation, I foolishly...
# 496    On XX/XX/XXXX I had went to see if I can get a...
# 497    XXXX XXXX and XXXX  XXXX XXXX are reporting ne...
# 498    On XX/XX/2018- I was loaned {$600.00} via onli...
# 499    My credit report states that I was late on pay...
# Name: input, Length: 500, dtype: object

# %% [markdown]
# ### Clean punctuations

# %%
import re
def clean_punctuation(text):
    # Define a regular expression pattern to match punctuation and special characters
    # Matches any character that is not a word character (\w), space (\s), or underscore (_)
    punctuation_pattern = re.compile(r'[^\w\s]|_')

    # Replace punctuation and special characters with an empty string
    cleaned_text = re.sub(punctuation_pattern, '', text)

    return cleaned_text

data_cleaned = [clean_punctuation(row) for row in data['input']]

# %%
data_cleaned[2]
# Out:
# 'Over the past 2 weeks I have been receiving excessive amounts of telephone calls from the company listed in this complaint The calls occur between XXXX XXXX and XXXX XXXX to my cell and at my job The company does not have the right to harass me at work and I want this to stop It is extremely distracting to be told 5 times a day that I have a call from this collection agency while at work'

# %% [markdown]
# ### Tokenize the word

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Download NLTK resources (if not already downloaded)
nltk.download('stopwords')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt_tab to /home/jovyan/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
token = [nltk.word_tokenize(row) for row in data_cleaned]

# %%
print(token[0])
# Out:
# ['transworld', 'systems', 'inc', 'is', 'trying', 'to', 'collect', 'a', 'debt', 'that', 'is', 'not', 'mine', 'not', 'owed', 'and', 'is', 'inaccurate']

# %%
print(token[1])
# Out:
# ['I', 'would', 'like', 'to', 'request', 'the', 'suppression', 'of', 'the', 'following', 'items', 'from', 'my', 'credit', 'report', 'which', 'are', 'the', 'result', 'of', 'my', 'falling', 'victim', 'to', 'identity', 'theft', 'This', 'information', 'does', 'not', 'relate', 'to', 'transactions', 'that', 'I', 'have', 'madeaccounts', 'that', 'I', 'have', 'opened', 'as', 'the', 'attached', 'supporting', 'documentation', 'can', 'attest', 'As', 'such', 'it', 'should', 'be', 'blocked', 'from', 'appearing', 'on', 'my', 'credit', 'report', 'pursuant', 'to', 'section', '605B', 'of', 'the', 'Fair', 'Credit', 'Reporting', 'Act']

# %% [markdown]
# ### Filter stop words

# %%
stop_words = set(stopwords.words('english'))

# %%
complaint_filtered = []
for i, row in enumerate(token):
    row_filtered = [word for word in row if word.lower() not in stop_words]
    complaint_filtered.append(row_filtered)

# %%
print(complaint_filtered[1])
# Out:
# ['would', 'like', 'request', 'suppression', 'following', 'items', 'credit', 'report', 'result', 'falling', 'victim', 'identity', 'theft', 'information', 'relate', 'transactions', 'madeaccounts', 'opened', 'attached', 'supporting', 'documentation', 'attest', 'blocked', 'appearing', 'credit', 'report', 'pursuant', 'section', '605B', 'Fair', 'Credit', 'Reporting', 'Act']

# %% [markdown]
# ### Perform lemmatization

# %%
import spacy

# Load the spaCy English model
nlp = spacy.load('en_core_web_sm')

# %%
complaint_lemma = []
for i, row in enumerate(complaint_filtered):
    doc = nlp(' '.join(complaint_filtered[i]))
    lemmatized_tokens = [token.lemma_ for token in doc]
    complaint_lemma.append(lemmatized_tokens)

# %%
print(complaint_lemma[1])
# Out:
# ['would', 'like', 'request', 'suppression', 'follow', 'item', 'credit', 'report', 'result', 'fall', 'victim', 'identity', 'theft', 'information', 'relate', 'transaction', 'madeaccount', 'open', 'attached', 'support', 'documentation', 'attest', 'block', 'appear', 'credit', 'report', 'pursuant', 'section', '605B', 'Fair', 'Credit', 'Reporting', 'Act']

# %% [markdown]
# ## Train model

# %%
# %pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.3.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /opt/conda/lib/python3.11/site-packages (from gensim) (1.26.4)
# Collecting scipy<1.14.0,>=1.7.0 (from gensim)
#   Downloading scipy-1.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/conda/lib/python3.11/site-packages (from gensim) (7.3.1)
# Requirement already satisfied: wrapt in /opt/conda/lib/python3.11/site-packages (from smart-open>=1.8.1->gensim) (1.17.3)
# Downloading gensim-4.3.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.7/26.7 MB 5.4 MB/s eta 0:00:0000:0100:01
# Downloading scipy-1.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 5.5 MB/s eta 0:00:0000:0100:01
# Installing collected packages: scipy, gensim
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.2
#     Uninstalling scipy-1.16.2:
#       Successfully uninstalled scipy-1.16.2
# Successfully installed gensim-4.3.3 scipy-1.13.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from gensim.models import Word2Vec
model = Word2Vec(complaint_lemma, min_count=1,vector_size= 300,workers=5, window=10, sg = 1, epochs=100)

# %%
model.wv['debt']
# Out:
# array([-5.38597405e-01,  5.26972055e-01, -5.57641573e-02, -1.09658554e-01,
#         1.10966310e-01,  1.83833137e-01,  4.90156561e-01,  1.35466084e-01,
#        -1.98401827e-02,  4.20830607e-01, -1.77549511e-01, -3.43484372e-01,
#        -1.72464415e-01, -2.04046100e-01, -9.07163545e-02,  9.16675292e-03,
#        -7.13892281e-02, -1.70121714e-02, -4.39662151e-02,  4.14326429e-01,
#        -5.80090821e-01,  4.76181926e-03, -1.46296620e-01, -3.12335372e-01,
#        -3.72122943e-01, -7.91606754e-02, -3.67898583e-01, -3.17427337e-01,
#        -3.51279019e-03, -1.83840737e-01,  4.57011908e-02, -6.55891001e-01,
#        -5.24104051e-02, -7.86534846e-02, -2.64793754e-01, -4.19654608e-01,
#        -3.93175870e-01, -1.35037024e-03,  4.44175661e-01, -3.92465264e-01,
#        -2.15048924e-01, -1.03617594e-01,  5.48912100e-02, -2.07396671e-02,
#         2.95400452e-02,  3.02264839e-01,  4.54836525e-02,  2.71085680e-01,
#        -7.27267265e-02,  1.51113957e-01, -1.76448282e-02,  1.00615062e-02,
#         2.16165558e-01, -8.67410526e-02,  7.94121027e-02, -1.07898757e-01,
#         9.88583341e-02, -1.69730783e-01,  5.18218987e-02,  7.10805431e-02,
#        -5.30128777e-01, -3.39048803e-01,  2.94907153e-01,  8.66440162e-02,
#         2.78897673e-01,  8.36361274e-02, -2.57935584e-01,  1.00142911e-01,
#        -2.92331189e-01, -3.56001943e-01,  3.49596292e-01,  3.18328619e-01,
#         6.15594923e-01,  1.26876764e-03,  2.30253398e-01, -1.48477003e-01,
#        -3.59649748e-01,  9.66492221e-02, -3.33720118e-01,  3.20713520e-01,
#        -1.88471571e-01,  6.47085682e-02,  2.83192039e-01,  7.73302466e-02,
#         5.06293714e-01, -2.01592490e-01, -2.10906386e-01, -4.67690289e-01,
#         2.49487177e-01, -1.06266327e-01,  9.10862386e-02, -3.68708558e-02,
#         3.32519352e-01, -2.46567219e-01, -2.34888256e-01, -5.57258241e-02,
#         1.39891699e-01,  2.48602316e-01, -2.49630511e-01, -4.60187584e-01,
#         7.77136385e-01,  2.14913681e-01, -4.47563052e-01,  6.68406188e-02,
#        -2.14069054e-01,  1.24742657e-01, -3.07926029e-01, -5.81681550e-01,
#        -1.86223507e-01,  2.83492446e-01,  6.21085018e-02,  3.52907866e-01,
#         2.03298181e-01, -1.13145910e-01, -3.07831913e-02,  2.69343585e-01,
#         1.57631822e-02, -3.66447628e-01,  3.38236600e-01, -1.61702037e-01,
#         5.69988608e-01,  1.85007557e-01,  1.27656072e-01,  1.63154215e-01,
#         9.80741531e-02,  1.61566750e-05,  7.72887096e-02,  1.71698704e-02,
#        -2.89743096e-01,  1.28457487e-01,  1.11209862e-01, -1.57042127e-02,
#         5.44262528e-01,  8.45018849e-02, -2.50782281e-01, -2.58942187e-01,
#         9.50232074e-02, -9.05495062e-02,  8.22233856e-02, -1.38632506e-01,
#        -2.28008747e-01,  3.56700957e-01,  3.48750710e-01, -1.02364652e-01,
#         7.62649104e-02,  1.35705069e-01,  7.80961439e-02,  1.49101838e-01,
#         5.57825528e-02,  1.53223962e-01, -3.04775596e-01, -1.47372335e-01,
#        -2.46044531e-01, -4.37852204e-01, -1.72192067e-01, -2.44627014e-01,
#        -2.71653563e-01,  1.94205105e-01, -2.40337819e-01, -1.18021123e-01,
#         1.78955287e-01, -3.33744168e-01,  5.86177558e-02,  3.79290104e-01,
#        -5.77899180e-02, -2.97722667e-01,  1.62660971e-01, -1.19146764e-01,
#        -3.45895797e-01,  1.64190084e-01, -2.61545062e-01, -4.06136841e-01,
#        -4.60683703e-02, -1.94227844e-01,  2.46483684e-01, -4.98928219e-01,
#         2.34779671e-01, -7.37500340e-02, -3.01112235e-01, -1.99865736e-02,
#        -1.60578340e-01, -4.21492428e-01, -5.03721297e-01,  1.55107826e-02,
#        -4.19054121e-01, -4.30433393e-01,  2.27326900e-01,  3.38831186e-01,
#        -3.16452652e-01, -1.34586319e-01,  1.21856704e-02,  1.86594129e-02,
#        -2.55134344e-01, -3.38524222e-01,  2.43035972e-01, -4.64104384e-01,
#        -2.05847576e-01,  4.18610573e-02,  1.34782985e-01,  1.42671287e-01,
#         1.46919504e-01,  3.14595371e-01,  2.36835815e-02,  2.09139422e-01,
#         5.81994355e-02, -4.64159735e-02, -1.23682506e-01, -1.10368282e-01,
#        -2.46603414e-02,  7.75989071e-02, -3.61868978e-01, -1.34353459e-01,
#         6.20621555e-02,  2.80116171e-01,  4.40672278e-01, -3.47809255e-01,
#         4.38398048e-02, -2.54267395e-01, -3.33361700e-02, -2.60432899e-01,
#        -1.96868509e-01, -6.46816846e-03, -1.21510029e-02,  3.21812838e-01,
#         4.23986942e-01,  2.53128409e-01,  2.22436205e-01,  4.08842713e-02,
#         2.14128286e-01,  8.11259896e-02,  1.27800614e-01,  1.06494717e-01,
#         1.30804628e-01, -1.40428379e-01,  2.55839318e-01, -1.43767402e-01,
#         3.35001558e-01, -6.07712269e-02,  1.63129941e-01, -1.18565731e-01,
#        -3.83008331e-01, -1.14818200e-01, -1.63599119e-01, -1.08687483e-01,
#        -1.46062568e-01, -3.48959029e-01, -5.23209095e-01, -9.56747830e-02,
#        -1.69196039e-01, -3.43149930e-01, -4.11626361e-02,  1.69968128e-01,
#         3.44397664e-01,  9.91015732e-02, -2.75463909e-01, -4.01102394e-01,
#         3.52885038e-01,  4.17851418e-01,  5.95936365e-02, -3.27158757e-02,
#         2.97454804e-01,  1.64518088e-01,  1.89466774e-01, -6.22899085e-02,
#         9.15165469e-02, -5.19662797e-01, -3.21697474e-01,  7.68406242e-02,
#        -5.59507549e-01, -4.10361469e-01,  8.55257809e-02,  1.88227728e-01,
#         1.91702411e-01, -2.78096557e-01, -2.11664379e-01, -1.35462433e-01,
#         2.00485483e-01, -1.22553386e-01, -5.41346669e-01,  2.85736591e-01,
#        -3.34413260e-01,  1.82777926e-01, -1.80866361e-01, -3.76708396e-02,
#        -1.86941419e-02,  1.50707528e-01,  3.18965949e-02,  2.04855129e-01,
#         8.84873569e-02,  3.05709273e-01,  4.00888652e-01,  2.92601269e-02,
#        -2.23872170e-01,  3.19263250e-01,  3.50215107e-01,  1.61497831e-01,
#        -3.77035402e-02, -1.90655068e-01, -2.43117481e-01, -7.42791966e-02],
#       dtype=float32)

# %% [markdown]
# ## Find the most similar words to "debt", "collection", and "risk"

# %%
words = ['debt', 'collection', 'risk']

for i, word in enumerate(word):
