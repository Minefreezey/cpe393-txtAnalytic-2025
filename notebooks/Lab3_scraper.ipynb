# %% [markdown]
# # Web Scraper

# %%
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# Require input is the URL.

# %%
url = 'https://www.britannica.com/topic/list-of-state-capitals-in-the-United-States-2119210'
page = requests.get(url)
soup = BeautifulSoup(page.text, 'html')
# print(soup)

# %% [markdown]
# Find all tables in the page. In this website, though, there's only one so it's simple.

# %%
soup.find_all('table')
# Out:
# [<table data-sortable-table="true"> <thead> <tr> <th data-col-type="text" data-sortable-type="alpha">state</th> <th data-col-type="text" data-sortable-type="alpha">capital</th> <th data-col-type="number" data-sortable-type="numeric">population of capital: census</th> <th data-col-type="number" data-sortable-type="numeric">population of capital: estimated</th> </tr> </thead> <tbody> <tr> <td><a class="md-crosslink sortable" data-show-preview="true" href="https://www.britannica.com/place/Alabama-state">Alabama</a></td> <td><a class="md-crosslink sortable" data-show-preview="true" href="https://www.britannica.com/place/Montgomery-Alabama">Montgomery</a></td> <td>(2020) 200,603</td> <td>(2021 est.) 198,665</td> </tr> <tr> <td><a class="md-crosslink sortable" data-show-preview="true" href="https://www.britannica.com/place/Alaska">Alaska</a></td> <td><a class="md-crosslink sortable" data-show-preview="true" href="https://www.britannica.com/place/Juneau">Juneau</a></td> <td>(2020) 32,255</td> <td>(2021 est.) 31,973</td> </tr> <tr> <td><a class="md-crosslink sortable" data-show-preview="true" href="https://www.britannica.com/place/Arizona-state">Arizona</a></td> <td><a class="md-crosslink sortable" data-show-preview="true" href="https://www.britannica.com/place/Phoenix-Arizona">Phoenix</a></td> <td>(2020) 1,608,139</td> <td>(2021 est.) 1,624,569</td> </tr> <tr> <td><a class="md-crosslink sortable" data-show-preview="true" href="https://www.britannica.com/place/Arkansas-state">Arkansas</a></td> <td><a class="md-crosslink sortable" data-show-preview="true" href="https://www.britannica.com/place/Little-Rock">Little Rock</a></td> <td>(2020) 202,591</td> <td>(2021 est.) 201,998</td> </tr> <tr> <td><a class="md-crosslink sortable" data-show-preview="true" href="https://www.britannica.com/place/California-state">California</a></td> <td><a class="md-crosslink sortable" data-show-preview="true" href="https://www.britannica.com/place/Sacramento-California">Sacramento</a></td> <td>(2020) 524,943</td> <td>(2021 est.) 525,041</td> </tr> <tr> <td><a class="md-crosslink sortable" data-show-preview="true" href="https://www.britannica.com/place/Colorado-state">Colorado</a></td> <td><a class="md-crosslink sortable" data-show-preview="true" href="https://www.britannica.com/place/Denver">Denver</a></td> <td>(2020) 715,522</td> <td>(2021 est.) 711,463</td> </tr> <tr> <td><a class="md-crosslink sortable" data-show-preview="true" href="https://www.britannica.com/place/Connecticut">Connecticut</a></td> <td><a class="md-crosslink sortable" data-show-preview="true" href="https://www.britannica.com/place/Hartford-Connecticut">Hartford</a></td> <td>(2020) 121,054</td> <td>(2021 est.) 120,576</td> </tr> <tr> <td><a class="md-crosslink sortable" data-show-preview="true" href="https://www.britannica.com/place/Delaware-state">Delaware</a></td> <td><a class="md-crosslink sortable" data-show-preview="true" href="https://www.britannica.com/place/Dover-Delaware">Dover</a></td> <td>(2020) 39,403</td> <td>(2021 est.) 38,992</td> </tr> <tr> <td><a class="md-crosslink sortable" data-show-preview="true" href="https://www.britannica.com/place/Florida">Florida</a></td> <td><a class="md-crosslink sortable" data-show-preview="true" href="https://www.britannica.com/place/Tallahassee">Tallahassee</a></td> <td>(2020) 196,068</td> <td>(2021 est.) 197,102</td> </tr> <tr> <td><a class="md-crosslink sortable" data-show-preview="true" href="https://www.britannica.com/place/Georgia-state">Georgia</a></td> <td><a class="md-crosslink sortable" data-show-preview="true" href="https://www.britannica.com/place/Atlanta-Georgia">Atlanta</a></td> <td>(2020) 498,715</td> <td>(2021 est.) 496,461</td> </tr> <tr> <td><a class="md-crosslink sortable" data-show-preview="true" href="https://www.britannica.com/place/Hawaii-state">Hawaii</a></td> <td><a class="md-crosslink sortable" data-show-preview="true" href="https://www.britannica.com/place/Honolulu">Honolulu</a></td> <td>(2020) 350,964</td> <td>(202 ...

# %% [markdown]
# Let's first get just the title of the table.
#
# *Note: `<th>` tag defines a header cell in an HTML table*

# %%
titles = soup.find_all('th')
titles
# Out:
# [<th data-col-type="text" data-sortable-type="alpha">state</th>,
#  <th data-col-type="text" data-sortable-type="alpha">capital</th>,
#  <th data-col-type="number" data-sortable-type="numeric">population of capital: census</th>,
#  <th data-col-type="number" data-sortable-type="numeric">population of capital: estimated</th>]

# %% [markdown]
# Since we do not need the tags, let's clean up the data.

# %%
titles_list = [title.text for title in titles]
titles_list
# Out:
# ['state',
#  'capital',
#  'population of capital: census',
#  'population of capital: estimated']

# %% [markdown]
# If the output still contains newline and other symbols that are not needed, you can further clean the data using, for example, ```.strip()```

# %% [markdown]
# Next, create a dataframe

# %%
import pandas as pd

df = pd.DataFrame(columns = titles_list)
df
# Out:
# Empty DataFrame
# Columns: [state, capital, population of capital: census, population of capital: estimated]
# Index: []

# %% [markdown]
# Let's scrape the remaining data and fill this table!

# %%
rows = soup.find_all('tr')
len(rows)
# Out:
# 51

# %% [markdown]
# The data of our interest are within the scope of **td** tags.
#
# *Note: `<td>` tag defines a standard data cell in an HTML table.*

# %%
# -- Long version --
# row_data = []
# for row in rows:
#   row_data.append(row.find_all('td'))

# -- Short version --
row_data = [row.find_all('td') for row in rows]
row_data
# Out:
# [[],
#  [<td><a class="md-crosslink sortable" data-show-preview="true" href="https://www.britannica.com/place/
a></td>,
#   <td><a class="md-crosslink sortable" data-show-preview="true" href="https://www.britannica.com/place/Salt-Lake-City">Salt Lake City</a></td>,
#   <td>(2020) 199,723</td>,
#   <td>(2021 est.) 200,478</td>],
#  [<td><a class="md-crosslink sortable" data-show-preview="true" href="https://www.britannica.com/place/Vermont">Vermont</a></td>,
#   <td><a class="md-crosslink sortable" data-show-preview="true" href="https://www.britannica.com/place/Montpelier-Vermont">Montpelier</a></td>,
#   <td>(2020) 8,074</td>,
#   <td>(2021 est.) 8,002</td>],
#  [<td><a class="md-crosslink sortable" data-show-preview="true" href="https://www.britannica.com/place/Virginia-state">Virginia</a></td>,
#   <td><a class="md-crosslink sortable" data-show-preview="true" href="https://www.britannica.com/place/Richmond-Virginia">Richmond</a></td>,
#   <td>(2020) 226,610</td>,
#   <td>(2021 est.) 226,604</td>],
#  [<td><a class="md-crosslink sortable" data-show-preview="true" href="https://www.britannica.com/place/Washington-state">Washington</a></td>,
#   <td><a class="md-crosslink sortable" data-show-preview="true" href="https://www.britannica.com/place/Olympia-Washington">Olympia</a></td>,
#   <td>(2020) 55,605</td>,
#   <td>(2021 est.) 55,919</td>],
#  [<td><a class="md-crosslink sortable" data-show-preview="true" href="https://www.britannica.com/place/West-Virginia">West Virginia</a></td>,
#   <td><a class="md-crosslink sortable" data-show-preview="true" href="https://www.britannica.com/place/Charleston-West-Virginia">Charleston</a></td>,
#   <td>(2020) 48,864</td>,
#   <td>(2021 est.) 48,018</td>],
#  [<td><a class="md-crosslink sortable" data-show-preview="true" href="https://www.britannica.com/place/Wisconsin">Wisconsin</a></td>,
#   <td><a class="md-crosslink sortable" data-show-preview="true" href="https://www.britannica.com/place/Madison-Wisconsin">Madison</a></td>,
#   <td>(2020) 269,840</td>,
#   <td>(2021 est.) 269,196</td>],
#  [<td><a class="md-crosslink sortable" data-show-preview="true" href="https://www.britannica.com/place/Wyoming-state">Wyoming</a></td>,
#   <td><a class="md-crosslink sortable" data-show-preview="true" href="https://www.britannica.com/place/Cheyenne-Wyoming">Cheyenne</a></td>,
#   <td>(2020) 65,132</td>,
#   <td>(2021 est.) 65,051</td>]]

# %% [markdown]
# The first row collected has no value, thus an empty list.

# %%
row_data[0]
# Out:
# []

# %% [markdown]
# Turns out the first row is actually here

# %%
row_data[1]
# Out:
# [<td><a class="md-crosslink sortable" data-show-preview="true" href="https://www.britannica.com/place/Alabama-state">Alabama</a></td>,
#  <td><a class="md-crosslink sortable" data-show-preview="true" href="https://www.britannica.com/place/Montgomery-Alabama">Montgomery</a></td>,
#  <td>(2020) 200,603</td>,
#  <td>(2021 est.) 198,665</td>]

# %% [markdown]
# However, we only want the text portion.

# %%
print(row_data[1][0].text)
print(row_data[1][1].text)
print(row_data[1][2].text)
print(row_data[1][3].text)
# Out:
# Alabama
# Montgomery
# (2020) 200,603
# (2021 est.) 198,665

# %% [markdown]
# Therefore, more cleaning is necessary.

# %% [markdown]
# Add the remaining rows to the dataframe.
#
# But does this code work?

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [state, capital, population of capital: census, population of capital: estimated]
# Index: []

# %%
for each_row_data in row_data:
  state=[]
  for each_row_data_elem in each_row_data:
    state.append(each_row_data_elem.text)

  length = len(df)
  df.loc[length] = state
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 7
#       4   state.append(each_row_data_elem.text)
#       6 length = len(df)
# ----> 7 df.loc[length] = state
#
# File /opt/conda/lib/python3.13/site-packages/pandas/core/indexing.py:911, in _LocationIndexer.__setitem__(self, key, value)
#     908 self._has_valid_setitem_indexer(key)
#     910 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 911 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File /opt/conda/lib/python3.13/site-packages/pandas/core/indexing.py:1932, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1929     indexer, missing = convert_missing_indexer(indexer)
#    1931     if missing:
# -> 1932         self._setitem_with_indexer_missing(indexer, value)
#    1933         return
#    1935 if name == "loc":
#    1936     # must come after setting of missing
#
# File /opt/conda/lib/python3.13/site-packages/pandas/core/indexing.py:2306, in _iLocIndexer._setitem_with_indexer_missing(self, indexer, value)
#    2303     if is_list_like_indexer(value):
#    2304         # must have conforming columns
#    2305         if len(value) != len(self.obj.columns):
# -> 2306             raise ValueError("cannot set a row with mismatched columns")
#    2308     value = Series(value, index=self.obj.columns, name=indexer)
#    2310 if not len(self.obj):
#    2311     # We will ignore the existing dtypes instead of using
#    2312     #  internals.concat logic
#
# ValueError: cannot set a row with mismatched columns

# %%
df
# Out:
# Empty DataFrame
# Columns: [state, capital, population of capital: census, population of capital: estimated]
# Index: []

# %% [markdown]
# TODO:
#
# - Scrape other table from wikipedia
# - Generate a new table/tables using dataframe
# - Feel free to use other html tags
# - Clean & preprocess
#
# ---
#
# Other websites (for instance)
# - https://www.timesjobs.com/
# - https://www.tripadvisor.com/
